# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
#print(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Url From openweather for API call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# creating empty Lists for storing values and generating url
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

# generation set of 50

i=1
def cities_chunks(cities, n): 
      
    # looping till length l 
    for i in range(0, len(cities), n):  
        yield cities[i:i + n]
        
        #i+=i
        
n = 50

#print(i, city)

group_city = list(cities_chunks(cities, n)) 
#print (group_city)

# for i in List[0]:
#     print(i)

# for i in List[0]:
#     print(i)
print('Bigining Data Retrival')
print('----------------------------------')

c=1
j=0
for list1 in group_city:
    #j=0
    for city in list1:

        
        city=city
        query_url = f'{base_url}appid={weather_api_key}&q={city}'
        #response = requests.get(query_url).json()
  

    
    

        try:

            #         cloudiness.append(response["clouds"]["all"])
            #         country.append(response["sys"]["country"])
            #         date.append(response["dt"])
            #         max_temp.append(response["main"]['temp_max'])
            #         humidity.append(response["main"]['humidity'])
            #         lat.append(response["coord"]["lat"])  
            #         lng.append(response["coord"]["lon"])
            #         wind_speed.append(response["wind"]["speed"])
            #         city_name.append(response["name"])



            print(f'Processing record {i} of Set{c}|{city}')
            print(f'{query_url}')
            c+=1


        except (KeyError):

            print("City not found. Skipping.....")

            time.sleep(1)
    i+=1
    j+=1 
print('----------------------------------')        
print('End Data Retrival')
# Out:
# Bigining Data Retrival
# ----------------------------------
# Processing record 0 of Set1|punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=punta arenas
# Processing record 0 of Set2|barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=barentsburg
# Processing record 0 of Set3|kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kaitangata
# Processing record 0 of Set4|cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cayenne
# Processing record 0 of Set5|barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=barrow
# Processing record 0 of Set6|yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yellowknife
# Processing record 0 of Set7|stepnyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=stepnyak
# Processing record 0 of Set8|san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=san cristobal
# Processing record 0 of Set9|rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=rikitea
# Processing record 0 of Set10|zarubino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=zarubino
# Processing record 0 of Set11|albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=albany
# Processing record 0 of Set12|ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ushuaia
# Processing record 0 of Set13|taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=taolanaro
# Processing record 0 of Set14|attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=attawapiskat
# Processing record 0 of Set15|akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=akyab
# Processing record 0 of Set16|jiaojiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=jiaojiang
# Processing record 0 of Set17|stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=stornoway
# Processing record 0 of Set18|halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=halalo
# Processing record 0 of Set19|greifswald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=greifswald
# Processing record 0 of Set20|mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mahadday weyne
# Processing record 0 of Set21|hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hobyo
# Processing record 0 of Set22|upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=upernavik
# Processing record 0 of Set23|esso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=esso
# Processing record 0 of Set24|qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=qaanaaq
# Processing record 0 of Set25|hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hermanus
# Processing record 0 of Set26|thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=thompson
# Processing record 0 of Set27|iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=iquique
# Processing record 0 of Set28|soskovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=soskovo
# Processing record 0 of Set29|mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mattru
# Processing record 0 of Set30|kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kapaa
# Processing record 0 of Set31|tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tucuman
# Processing record 0 of Set32|muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=muros
# Processing record 0 of Set33|subaytilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=subaytilah
# Processing record 0 of Set34|busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=busselton
# Processing record 0 of Set35|amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=amderma
# Processing record 0 of Set36|kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kedrovyy
# Processing record 0 of Set37|tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tsihombe
# Processing record 0 of Set38|mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mataura
# Processing record 0 of Set39|pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pangnirtung
# Processing record 0 of Set40|laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=laguna
# Processing record 0 of Set41|hernani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hernani
# Processing record 0 of Set42|east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=east london
# Processing record 0 of Set43|puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=puerto ayora
# Processing record 0 of Set44|port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port lincoln
# Processing record 0 of Set45|ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ahuimanu
# Processing record 0 of Set46|pirna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pirna
# Processing record 0 of Set47|krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=krasnoselkup
# Processing record 0 of Set48|karangasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=karangasem
# Processing record 0 of Set49|epe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=epe
# Processing record 0 of Set50|port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port elizabeth
# Processing record 1 of Set51|lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lebu
# Processing record 1 of Set52|eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=eenhana
# Processing record 1 of Set53|kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kodiak
# Processing record 1 of Set54|wadi maliz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=wadi maliz
# Processing record 1 of Set55|sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sao joao da barra
# Processing record 1 of Set56|ode
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ode
# Processing record 1 of Set57|egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=egvekinot
# Processing record 1 of Set58|hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hamilton
# Processing record 1 of Set59|dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=dikson
# Processing record 1 of Set60|kokoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kokoda
# Processing record 1 of Set61|hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hobart
# Processing record 1 of Set62|mugla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mugla
# Processing record 1 of Set63|karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=karaul
# Processing record 1 of Set64|acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=acarau
# Processing record 1 of Set65|illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=illoqqortoormiut
# Processing record 1 of Set66|barabinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=barabinsk
# Processing record 1 of Set67|tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tiksi
# Processing record 1 of Set68|castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=castro
# Processing record 1 of Set69|san fernando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=san fernando
# Processing record 1 of Set70|riverton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=riverton
# Processing record 1 of Set71|provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=provideniya
# Processing record 1 of Set72|kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kavieng
# Processing record 1 of Set73|viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=viedma
# Processing record 1 of Set74|natchez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=natchez
# Processing record 1 of Set75|cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cape town
# Processing record 1 of Set76|ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ostrovnoy
# Processing record 1 of Set77|port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port alfred
# Processing record 1 of Set78|yunyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yunyang
# Processing record 1 of Set79|ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ancud
# Processing record 1 of Set80|oinoussai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=oinoussai
# Processing record 1 of Set81|ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ahipara
# Processing record 1 of Set82|lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lerwick
# Processing record 1 of Set83|sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sterling
# Processing record 1 of Set84|margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=margate
# Processing record 1 of Set85|eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=eureka
# Processing record 1 of Set86|biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=biloela
# Processing record 1 of Set87|chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=chokurdakh
# Processing record 1 of Set88|dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=dingle
# Processing record 1 of Set89|sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sitka
# Processing record 1 of Set90|georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=georgetown
# Processing record 1 of Set91|new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=new norfolk
# Processing record 1 of Set92|bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bluff
# Processing record 1 of Set93|kushmurun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kushmurun
# Processing record 1 of Set94|cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cockburn town
# Processing record 1 of Set95|skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=skjervoy
# Processing record 1 of Set96|pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pitimbu
# Processing record 1 of Set97|tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tuktoyaktuk
# Processing record 1 of Set98|butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=butaritari
# Processing record 1 of Set99|udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=udachnyy
# Processing record 1 of Set100|vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vila velha
# Processing record 2 of Set101|bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bredasdorp
# Processing record 2 of Set102|constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=constitucion
# Processing record 2 of Set103|rajgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=rajgarh
# Processing record 2 of Set104|avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=avarua
# Processing record 2 of Set105|krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=krasnoarmeysk
# Processing record 2 of Set106|batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=batticaloa
# Processing record 2 of Set107|jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=jamestown
# Processing record 2 of Set108|hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hilo
# Processing record 2 of Set109|xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=xining
# Processing record 2 of Set110|varniai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=varniai
# Processing record 2 of Set111|nouna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nouna
# Processing record 2 of Set112|cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cidreira
# Processing record 2 of Set113|bjorkelangen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bjorkelangen
# Processing record 2 of Set114|mundra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mundra
# Processing record 2 of Set115|baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=baherden
# Processing record 2 of Set116|siruguppa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=siruguppa
# Processing record 2 of Set117|kerki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kerki
# Processing record 2 of Set118|richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=richards bay
# Processing record 2 of Set119|sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sentyabrskiy
# Processing record 2 of Set120|la union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=la union
# Processing record 2 of Set121|cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cherskiy
# Processing record 2 of Set122|hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hami
# Processing record 2 of Set123|anamur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=anamur
# Processing record 2 of Set124|victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=victoria
# Processing record 2 of Set125|jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=jizan
# Processing record 2 of Set126|luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=luderitz
# Processing record 2 of Set127|kulebaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kulebaki
# Processing record 2 of Set128|suining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=suining
# Processing record 2 of Set129|arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=arraial do cabo
# Processing record 2 of Set130|aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=aklavik
# Processing record 2 of Set131|mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mys shmidta
# Processing record 2 of Set132|san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=san ramon de la nueva oran
# Processing record 2 of Set133|la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=la ronge
# Processing record 2 of Set134|tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tupik
# Processing record 2 of Set135|marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=marzuq
# Processing record 2 of Set136|namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=namibe
# Processing record 2 of Set137|boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=boa vista
# Processing record 2 of Set138|hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hithadhoo
# Processing record 2 of Set139|kazanskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kazanskaya
# Processing record 2 of Set140|yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yerbogachen
# Processing record 2 of Set141|torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=torbay
# Processing record 2 of Set142|porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=porto novo
# Processing record 2 of Set143|sarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sarh
# Processing record 2 of Set144|shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=shache
# Processing record 2 of Set145|bialogard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bialogard
# Processing record 2 of Set146|mbala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mbala
# Processing record 2 of Set147|atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=atuona
# Processing record 2 of Set148|yangcun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yangcun
# Processing record 2 of Set149|itacoatiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=itacoatiara
# Processing record 2 of Set150|camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=camana
# Processing record 3 of Set151|bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bengkulu
# Processing record 3 of Set152|hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hohhot
# Processing record 3 of Set153|ganganagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ganganagar
# Processing record 3 of Set154|lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lorengau
# Processing record 3 of Set155|caxito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=caxito
# Processing record 3 of Set156|kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kushima
# Processing record 3 of Set157|batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=batsfjord
# Processing record 3 of Set158|tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tres arroyos
# Processing record 3 of Set159|bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bethel
# Processing record 3 of Set160|caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=caravelas
# Processing record 3 of Set161|mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mar del plata
# Processing record 3 of Set162|salaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=salaya
# Processing record 3 of Set163|berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=berdigestyakh
# Processing record 3 of Set164|saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=saskylakh
# Processing record 3 of Set165|coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=coahuayana
# Processing record 3 of Set166|chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=chuy
# Processing record 3 of Set167|novyy khushet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=novyy khushet
# Processing record 3 of Set168|husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=husavik
# Processing record 3 of Set169|itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=itarema
# Processing record 3 of Set170|baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=baykit
# Processing record 3 of Set171|mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mokhsogollokh
# Processing record 3 of Set172|smoky lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=smoky lake
# Processing record 3 of Set173|zabol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=zabol
# Processing record 3 of Set174|flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=flinders
# Processing record 3 of Set175|lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lolua
# Processing record 3 of Set176|tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tumannyy
# Processing record 3 of Set177|souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=souillac
# Processing record 3 of Set178|vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vaitupu
# Processing record 3 of Set179|tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tasiilaq
# Processing record 3 of Set180|varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=varhaug
# Processing record 3 of Set181|kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kamaishi
# Processing record 3 of Set182|lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lompoc
# Processing record 3 of Set183|kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kayes
# Processing record 3 of Set184|conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=conde
# Processing record 3 of Set185|geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=geraldton
# Processing record 3 of Set186|panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=panaba
# Processing record 3 of Set187|anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=anadyr
# Processing record 3 of Set188|rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=rawson
# Processing record 3 of Set189|hongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hongan
# Processing record 3 of Set190|honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=honningsvag
# Processing record 3 of Set191|isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=isangel
# Processing record 3 of Set192|sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sur
# Processing record 3 of Set193|la brea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=la brea
# Processing record 3 of Set194|maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=maniitsoq
# Processing record 3 of Set195|nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nikolskoye
# Processing record 3 of Set196|mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mahebourg
# Processing record 3 of Set197|nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nuevo progreso
# Processing record 3 of Set198|longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=longyearbyen
# Processing record 3 of Set199|guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=guerrero negro
# Processing record 3 of Set200|juifang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=juifang
# Processing record 4 of Set201|belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=belmonte
# Processing record 4 of Set202|mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mecca
# Processing record 4 of Set203|buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=buraydah
# Processing record 4 of Set204|mauganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mauganj
# Processing record 4 of Set205|astipalaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=astipalaia
# Processing record 4 of Set206|grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=grand river south east
# Processing record 4 of Set207|port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port augusta
# Processing record 4 of Set208|yecuatla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yecuatla
# Processing record 4 of Set209|atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=atambua
# Processing record 4 of Set210|ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ketchikan
# Processing record 4 of Set211|krasnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=krasnoye
# Processing record 4 of Set212|opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=opuwo
# Processing record 4 of Set213|kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kavaratti
# Processing record 4 of Set214|timra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=timra
# Processing record 4 of Set215|vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vaini
# Processing record 4 of Set216|saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=saint-francois
# Processing record 4 of Set217|grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=grootfontein
# Processing record 4 of Set218|redmond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=redmond
# Processing record 4 of Set219|mega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mega
# Processing record 4 of Set220|khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=khatanga
# Processing record 4 of Set221|mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mehamn
# Processing record 4 of Set222|salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=salalah
# Processing record 4 of Set223|bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bandarbeyla
# Processing record 4 of Set224|ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ixtapa
# Processing record 4 of Set225|nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nizhneyansk
# Processing record 4 of Set226|mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mount isa
# Processing record 4 of Set227|severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=severo-kurilsk
# Processing record 4 of Set228|nogliki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nogliki
# Processing record 4 of Set229|betare oya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=betare oya
# Processing record 4 of Set230|tumut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tumut
# Processing record 4 of Set231|matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=matamoros
# Processing record 4 of Set232|belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=belushya guba
# Processing record 4 of Set233|tsogni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tsogni
# Processing record 4 of Set234|cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cam ranh
# Processing record 4 of Set235|longonjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=longonjo
# Processing record 4 of Set236|luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=luanda
# Processing record 4 of Set237|hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hay river
# Processing record 4 of Set238|pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pevek
# Processing record 4 of Set239|carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=carutapera
# Processing record 4 of Set240|dera gopipur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=dera gopipur
# Processing record 4 of Set241|praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=praia da vitoria
# Processing record 4 of Set242|nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nelson bay
# Processing record 4 of Set243|juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=juneau
# Processing record 4 of Set244|kolda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kolda
# Processing record 4 of Set245|ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ponta do sol
# Processing record 4 of Set246|broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=broome
# Processing record 4 of Set247|huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=huarmey
# Processing record 4 of Set248|talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=talnakh
# Processing record 4 of Set249|katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=katsuura
# Processing record 4 of Set250|scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=scottsbluff
# Processing record 5 of Set251|dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=dwarka
# Processing record 5 of Set252|martinsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=martinsville
# Processing record 5 of Set253|shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=shingu
# Processing record 5 of Set254|vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vardo
# Processing record 5 of Set255|port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port shepstone
# Processing record 5 of Set256|manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=manggar
# Processing record 5 of Set257|lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lufilufi
# Processing record 5 of Set258|touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=touros
# Processing record 5 of Set259|kuandian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kuandian
# Processing record 5 of Set260|kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kimbe
# Processing record 5 of Set261|misratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=misratah
# Processing record 5 of Set262|brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=brae
# Processing record 5 of Set263|oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=oussouye
# Processing record 5 of Set264|wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=wilmington
# Processing record 5 of Set265|gorkovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=gorkovskiy
# Processing record 5 of Set266|ploemeur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ploemeur
# Processing record 5 of Set267|caluquembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=caluquembe
# Processing record 5 of Set268|shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=shimoda
# Processing record 5 of Set269|katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=katherine
# Processing record 5 of Set270|pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pisco
# Processing record 5 of Set271|port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=port blair
# Processing record 5 of Set272|chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=chapais
# Processing record 5 of Set273|quba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=quba
# Processing record 5 of Set274|mutsamudu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mutsamudu
# Processing record 5 of Set275|quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=quatre cocos
# Processing record 5 of Set276|saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=saleaula
# Processing record 5 of Set277|clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=clyde river
# Processing record 5 of Set278|faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=faanui
# Processing record 5 of Set279|airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=airai
# Processing record 5 of Set280|grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=grand centre
# Processing record 5 of Set281|vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vaitape
# Processing record 5 of Set282|portel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=portel
# Processing record 5 of Set283|tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tarko-sale
# Processing record 5 of Set284|labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=labuhan
# Processing record 5 of Set285|lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lucea
# Processing record 5 of Set286|mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mitu
# Processing record 5 of Set287|ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ribeira grande
# Processing record 5 of Set288|srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=srednekolymsk
# Processing record 5 of Set289|ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ilulissat
# Processing record 5 of Set290|kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kungurtug
# Processing record 5 of Set291|poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=poronaysk
# Processing record 5 of Set292|norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=norman wells
# Processing record 5 of Set293|higuey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=higuey
# Processing record 5 of Set294|mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mocambique
# Processing record 5 of Set295|longyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=longyan
# Processing record 5 of Set296|avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=avera
# Processing record 5 of Set297|paramonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=paramonga
# Processing record 5 of Set298|saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=saldanha
# Processing record 5 of Set299|huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=huilong
# Processing record 5 of Set300|ban dung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ban dung
# Processing record 6 of Set301|bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bambous virieux
# Processing record 6 of Set302|naral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=naral
# Processing record 6 of Set303|high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=high level
# Processing record 6 of Set304|iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=iracoubo
# Processing record 6 of Set305|vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vilyuysk
# Processing record 6 of Set306|solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=solnechnyy
# Processing record 6 of Set307|maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=maceio
# Processing record 6 of Set308|bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bilma
# Processing record 6 of Set309|yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yar-sale
# Processing record 6 of Set310|klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=klaksvik
# Processing record 6 of Set311|puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=puerto leguizamo
# Processing record 6 of Set312|barras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=barras
# Processing record 6 of Set313|cortez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=cortez
# Processing record 6 of Set314|tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tura
# Processing record 6 of Set315|beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=beringovskiy
# Processing record 6 of Set316|itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=itoman
# Processing record 6 of Set317|kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kodinsk
# ...
# Processing record 10 of Set521|muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=muisne
# Processing record 10 of Set522|teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=teguise
# Processing record 10 of Set523|matiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=matiri
# Processing record 10 of Set524|vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vila franca do campo
# Processing record 10 of Set525|oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=oktyabrskiy
# Processing record 10 of Set526|bosansko grahovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bosansko grahovo
# Processing record 10 of Set527|tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tomatlan
# Processing record 10 of Set528|mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mount gambier
# Processing record 10 of Set529|sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sorvag
# Processing record 10 of Set530|hanyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hanyang
# Processing record 10 of Set531|vinica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vinica
# Processing record 10 of Set532|lucapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lucapa
# Processing record 10 of Set533|muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=muzhi
# Processing record 10 of Set534|le vauclin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=le vauclin
# Processing record 10 of Set535|mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mackay
# Processing record 10 of Set536|nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nanortalik
# Processing record 10 of Set537|zharkent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=zharkent
# Processing record 10 of Set538|pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pemangkat
# Processing record 10 of Set539|mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mogadishu
# Processing record 10 of Set540|werneck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=werneck
# Processing record 10 of Set541|chicomuselo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=chicomuselo
# Processing record 10 of Set542|wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=wanning
# Processing record 10 of Set543|bolobo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bolobo
# Processing record 10 of Set544|guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=guarapari
# Processing record 10 of Set545|marjamaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=marjamaa
# Processing record 10 of Set546|mopipi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mopipi
# Processing record 10 of Set547|fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=fare
# Processing record 10 of Set548|tchibanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=tchibanga
# Processing record 10 of Set549|ussel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ussel
# Processing record 10 of Set550|badou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=badou
# Processing record 11 of Set551|mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mitsamiouli
# Processing record 11 of Set552|saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=saint-pierre
# Processing record 11 of Set553|rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=rungata
# Processing record 11 of Set554|khuzhir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=khuzhir
# Processing record 11 of Set555|bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bur gabo
# Processing record 11 of Set556|the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=the valley
# Processing record 11 of Set557|novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=novikovo
# Processing record 11 of Set558|korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=korla
# Processing record 11 of Set559|alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=alihe
# Processing record 11 of Set560|qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=qaqortoq
# Processing record 11 of Set561|pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=pontes e lacerda
# Processing record 11 of Set562|vestbygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vestbygda
# Processing record 11 of Set563|manaus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=manaus
# Processing record 11 of Set564|dafeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=dafeng
# Processing record 11 of Set565|san gavino monreale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=san gavino monreale
# Processing record 11 of Set566|henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=henties bay
# Processing record 11 of Set567|lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lavrentiya
# Processing record 11 of Set568|yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=yeppoon
# Processing record 11 of Set569|broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=broken hill
# Processing record 11 of Set570|alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=alotau
# Processing record 11 of Set571|sensuntepeque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sensuntepeque
# Processing record 11 of Set572|lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=lasa
# Processing record 11 of Set573|nanton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=nanton
# Processing record 11 of Set574|ankazobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ankazobe
# Processing record 11 of Set575|mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mabaruma
# Processing record 11 of Set576|singapore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=singapore
# Processing record 11 of Set577|inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=inhambane
# Processing record 11 of Set578|manuk mangkaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=manuk mangkaw
# Processing record 11 of Set579|hinton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hinton
# Processing record 11 of Set580|jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=jijiga
# Processing record 11 of Set581|sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sobolevo
# Processing record 11 of Set582|katha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=katha
# Processing record 11 of Set583|mentok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=mentok
# Processing record 11 of Set584|riberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=riberalta
# Processing record 11 of Set585|taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=taltal
# Processing record 11 of Set586|bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bathsheba
# Processing record 11 of Set587|kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kirakira
# Processing record 11 of Set588|alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=alugan
# Processing record 11 of Set589|sotnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sotnikovo
# Processing record 11 of Set590|holt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=holt
# Processing record 11 of Set591|soure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=soure
# Processing record 11 of Set592|emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=emerald
# Processing record 11 of Set593|asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=asau
# Processing record 11 of Set594|vicksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=vicksburg
# Processing record 11 of Set595|westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=westport
# Processing record 11 of Set596|kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kalianget
# Processing record 11 of Set597|sozimskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=sozimskiy
# Processing record 11 of Set598|minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=minab
# Processing record 11 of Set599|gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=gazanjyk
# Processing record 11 of Set600|fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=fortuna
# Processing record 12 of Set601|fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=fairbanks
# Processing record 12 of Set602|ingraj bazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=ingraj bazar
# Processing record 12 of Set603|xinxiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=xinxiang
# Processing record 12 of Set604|marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=marystown
# Processing record 12 of Set605|buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=buchanan
# Processing record 12 of Set606|meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=meyungs
# Processing record 12 of Set607|bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=bonavista
# Processing record 12 of Set608|hongjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=hongjiang
# Processing record 12 of Set609|xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=xai-xai
# Processing record 12 of Set610|halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=halifax
# Processing record 12 of Set611|gejiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=gejiu
# Processing record 12 of Set612|kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=kahului
# Processing record 12 of Set613|songjianghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=songjianghe
# Processing record 12 of Set614|samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=samusu
# Processing record 12 of Set615|horqueta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=horqueta
# Processing record 12 of Set616|galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=galveston
# Processing record 12 of Set617|puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=puerto carreno
# Processing record 12 of Set618|biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=biltine
# Processing record 12 of Set619|coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=coihaique
# Processing record 12 of Set620|semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=semnan
# Processing record 12 of Set621|huntington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=huntington
# Processing record 12 of Set622|aransas pass
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=aransas pass
# Processing record 12 of Set623|altar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=altar
# Processing record 12 of Set624|anyksciai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=66a72eb0e47a4deda8a3bdf1c0aece0d&q=anyksciai
# ----------------------------------
# End Data Retrival

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
